# %%
import numpy as np
import matplotlib.pyplot as plt

# Définir les poids du modèle appris
w0, w1, w2 = -3, 1.5, 0.8  

# Générer des points aléatoires pour les étudiants
np.random.seed(10)
X1 = np.random.uniform(1, 10, 100)  # Temps de révision
X2 = np.random.uniform(1, 10, 100)  # Heures de sommeil

# Calculer la fonction score et appliquer la sigmoïde
scores = w0 + w1 * X1 + w2 * X2
probs = 1 / (1 + np.exp(-scores))

# Définir la classe (1 si proba > 0.5, sinon 0)
y = (probs > 0.5).astype(int)

# Tracer les points
plt.figure(figsize=(8,6))
plt.scatter(X1[y == 1], X2[y == 1], color='blue', label="Réussite (1)")
plt.scatter(X1[y == 0], X2[y == 0], color='red', label="Échec (0)")

# Tracer la frontière de décision
x1_vals = np.linspace(1, 10, 100)
x2_vals = (-w0 - w1 * x1_vals) / w2  # Équation de la ligne de séparation
plt.plot(x1_vals, x2_vals, color='black', linestyle="--", label="Frontière de décision")

# Labels et légende
plt.xlabel("Temps de révision (h)")
plt.ylabel("Heures de sommeil (h)")
plt.title("Régression Logistique - Frontière de Décision")
plt.legend()
plt.show()
