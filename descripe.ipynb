# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/dataset_train.csv')

# %%
df.dropna(inplace=True,axis=0)

# %%
df.drop(columns=['Index'], inplace=True)

# %%
df
# Out:
#      Hogwarts House First Name    Last Name    Birthday Best Hand  Arithmancy  \
# 0         Ravenclaw     Tamara          Hsu  2000-03-30      Left     58384.0
# 1         Slytherin      Erich      Paredes  1999-10-14     Right     67239.0
# 2         Ravenclaw   Stephany        Braun  1999-11-03      Left     23702.0
# 3        Gryffindor      Vesta    Mcmichael  2000-08-19      Left     32667.0
# 5         Slytherin    Corrine      Hammond  1999-04-04     Right     21209.0
# ...             ...        ...          ...         ...       ...         ...
# 1595     Gryffindor       Jung        Blank  2001-09-14     Right     49009.0
# 1596      Slytherin     Shelli         Lock  1998-03-12      Left     63296.0
# 1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right     63905.0
# 1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left     82713.0
# 1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left     48639.0
#
#        Astronomy  Herbology  Defense Against the Dark Arts  Divination  \
# 0    -487.886086   5.727180                       4.878861       4.722
# 1    -552.060507  -5.987446                       5.520605      -5.612
# 2    -366.076117   7.725017                       3.660761       6.140
# 3     697.742809  -6.497214                      -6.977428       4.026
# 5    -613.687160  -4.289197                       6.136872      -6.592
# ...          ...        ...                            ...         ...
# 1595  354.280086  -4.541837                      -3.542801       5.702
# 1596  367.531174   6.061064                      -3.675312       1.757
# 1597  544.018925  -3.203269                      -5.440189       6.065
# 1598  453.676219   3.442831                      -4.536762       6.738
# 1599  688.911989   5.421046                      -6.889120       6.593
#
#       Muggle Studies  Ancient Runes  History of Magic  Transfiguration  \
# 0         272.035831     532.484226          5.231058      1039.788281
# 1        -487.340557     367.760303          4.107170      1058.944592
# 2         664.893521     602.585284          3.555579      1088.088348
# 3        -537.001128     523.982133         -4.809637       920.391449
# 5        -440.997704     396.201804          5.380286      1052.845164
# ...              ...            ...               ...              ...
# 1595     -497.235066     618.220213         -5.231721       964.219853
# 1596     -643.271092     445.827565          2.238112      1056.147366
# 1597     -385.150457     635.211486         -5.984257       953.866685
# 1598     -831.741123     383.444937          3.813111      1087.949205
# 1599     -234.207911     339.775154          7.208415      1034.928004
#
#         Potions  Care of Magical Creatures     Charms  Flying
# 0      3.790369                   0.715939 -232.79405  -26.89
# 1      7.248742                   0.091674 -252.18425 -113.45
# 2      8.728531                  -0.515327 -227.34265   30.42
# 3      0.821911                  -0.014040 -256.84675  200.64
# 5     11.751212                   1.049894 -247.94549  -34.69
# ...         ...                        ...        ...     ...
# 1595   3.389086                  -0.649983 -250.39401  185.83
# 1596   5.825263                  -0.333962 -246.42719   44.80
# 1597   1.709808                   0.071569 -251.63679  198.47
# 1598   3.904100                  -0.531875 -246.19072  -76.81
# 1599   2.052215                   0.150532 -244.02063  -54.77
#
# [1251 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Hogwarts House', 'First Name', 'Last Name', 'Birthday', 'Best Hand',
#        'Arithmancy', 'Astronomy', 'Herbology', 'Defense Against the Dark Arts',
#        'Divination', 'Muggle Studies', 'Ancient Runes', 'History of Magic',
#        'Transfiguration', 'Potions', 'Care of Magical Creatures', 'Charms',
#        'Flying'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Arithmancy    Astronomy    Herbology  Defense Against the Dark Arts  \
# count    1251.000000  1251.000000  1251.000000                    1251.000000
# mean    49453.109512    46.476449     1.189457                      -0.464764
# std     16701.553057   520.946093     5.223137                       5.209461
# min    -24370.000000  -966.740546   -10.295663                     -10.162119
# 25%     38180.000000  -485.323010    -4.252260                      -5.283460
# 50%     48793.000000   272.071636     3.526427                      -2.720716
# 75%     60794.500000   528.346042     5.463740                       4.853230
# max    104956.000000  1016.211940    10.296759                       9.667405
#
#         Divination  Muggle Studies  Ancient Runes  History of Magic  \
# count  1251.000000     1251.000000    1251.000000       1251.000000
# mean      3.213831     -222.903666     496.251457          2.978593
# std       4.110992      484.985850     106.710610          4.456963
# min      -8.727000    -1043.961527     283.869609         -8.431117
# 25%       3.120500     -573.969159     396.410014          2.230929
# 50%       4.621000     -419.164294     464.327598          4.402631
# 75%       5.727000      264.144523     597.516854          5.893868
# max      10.032000     1092.388611     745.396220         11.889713
#
#        Transfiguration      Potions  Care of Magical Creatures       Charms  \
# count      1251.000000  1251.000000                1251.000000  1251.000000
# mean       1029.862868     5.961276                  -0.064315  -243.325723
# std          43.982877     3.102918                   0.972646     8.790405
# min         906.627320    -3.620762                  -3.313676  -261.048920
# 25%        1025.640947     3.684157                  -0.694443  -250.585895
# 50%        1045.480657     5.868537                  -0.065116  -244.789150
# 75%        1058.327302     8.206667                   0.575599  -232.527830
# max        1094.460614    13.536762                   3.056546  -225.428140
#
#             Flying
# count  1251.000000
# mean     23.109009
# std      97.755017
# min    -181.470000
# 25%     -40.085000
# 50%      -1.920000
# 75%      52.625000
# max     279.070000

# %%
description = df.groupby('Hogwarts House').describe()
mean_only = description.loc[:, (slice(None), 'std')]
mean_only
# Out:
#                   Arithmancy   Astronomy Herbology  \
#                          std         std       std
# Hogwarts House
# Gryffindor      15137.524889  194.701731  2.344435
# Hufflepuff      15595.268510  159.791303  1.772203
# Ravenclaw       19107.607027  188.659992  1.921617
# Slytherin       16481.066706  149.584718  2.545890
#
#                Defense Against the Dark Arts Divination Muggle Studies  \
#                                          std        std            std
# Hogwarts House
# Gryffindor                          1.947017   1.484282     236.114707
# Hufflepuff                          1.597913   1.439173     176.227011
# Ravenclaw                           1.886600   1.529258     230.206092
# Slytherin                           1.495847   2.046731     172.232735
#
#                Ancient Runes History of Magic Transfiguration   Potions  \
#                          std              std             std       std
# Hogwarts House
# Gryffindor         39.360951         2.223386       24.508553  2.141069
# Hufflepuff         40.511375         2.194989       16.139960  2.441503
# Ravenclaw          42.318009         1.464055       15.901962  2.198852
# Slytherin          37.762661         1.953275       17.312453  1.783766
#
#                Care of Magical Creatures    Charms     Flying
#                                      std       std        std
# Hogwarts House
# Gryffindor                      0.996432  3.950940  46.467014
# Hufflepuff                      0.972982  1.746479  44.165845
# Ravenclaw                       0.977110  3.016032  34.521795
# Slytherin                       0.929005  3.797853  42.059667

# %%
df3
# Out:
# House   Statistic  Hufflepuff  Ravenclaw  Gryffindor  Slytherin   total
# 0           Count      415.00     351.00      261.00     224.00  1251.0
# 1      percentage       33.17      28.06       20.86      17.91   100.0

# %%
df['Arithmancy'] = df['Arithmancy'].astype(float)

# %%
df.head()

# %%
df.describe()

# %%
numeric_columns = df.select_dtypes(include=['number'])
numeric_columns

# %%
df.dtypes

# %%
df['Birthday'] = pd.to_datetime(df['Birthday'])

# %%
df.describe()
